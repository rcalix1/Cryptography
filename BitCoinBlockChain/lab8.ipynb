# %%
# Importing required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# Load the dataset
# Make sure the correct file path is provided, change this to your file location
data = pd.read_csv('/mnt/data/phishing_1.csv')

# Preprocess the data: Assuming the last column is the target and others are features
X = data.iloc[:, :-1].values  # Features (columns 1 to 30)
y = data.iloc[:, -1].values   # Class (last column)

# Standardize the features (important for certain algorithms)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Function to train and evaluate a classifier
def evaluate_model(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"Precision: {precision_score(y_test, y_pred, average='binary')}")
    print(f"Recall: {recall_score(y_test, y_pred, average='binary')}")
    print(f"F1 Score: {f1_score(y_test, y_pred, average='binary')}")

# Logistic Regression
print("Logistic Regression:")
evaluate_model(LogisticRegression())

# Decision Tree
print("\nDecision Tree:")
evaluate_model(DecisionTreeClassifier(random_state=42))

# Naive Bayes
print("\nNaive Bayes:")
evaluate_model(GaussianNB())

# Random Forest
print("\nRandom Forest:")
evaluate_model(RandomForestClassifier(random_state=42))
# Importing required libraries for TensorFlow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Load the dataset
data = pd.read_csv('/mnt/data/phishing_1.csv')

# Preprocess the data
X = data.iloc[:, :-1].values  # Features
y = data.iloc[:, -1].values   # Target

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# One-hot encode the labels (assuming binary classification, you can adjust this if it's multi-class)
encoder = OneHotEncoder(sparse_output=False)  # sparse=False is deprecated, use sparse_output=False
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Dense(30, input_dim=30, activation='relu'))  # Input layer (30 features)
model.add(Dense(15, activation='relu'))  # Hidden layer
model.add(Dense(2, activation='softmax'))  # Output layer (2 classes for one-hot encoded output)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=1)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy}')

# Predictions and converting back to class labels for evaluation
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Calculating Precision, Recall, and F1 Score
print(f"Precision: {precision_score(y_true, y_pred)}")
print(f"Recall: {recall_score(y_true, y_pred)}")
print(f"F1 Score: {f1_score(y_true, y_pred)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 14
#      10 from sklearn.ensemble import RandomForestClassifier
#      12 # Load the dataset
#      13 # Make sure the correct file path is provided, change this to your file location
# ---> 14 data = pd.read_csv('/mnt/data/phishing_1.csv')
#      16 # Preprocess the data: Assuming the last column is the target and others are features
#      17 X = data.iloc[:, :-1].values  # Features (columns 1 to 30)
#
# ...

# %%
pip install scikit-learn tensorflow pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
